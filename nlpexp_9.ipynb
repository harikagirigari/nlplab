# %% [markdown]
# <a href="https://colab.research.google.com/github/harikagirigari/nlplab/blob/main/nlpexp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 60.9 MB/s eta 0:00:00
# ...

# %%
import nltk
import urllib
import bs4 as bs
import re
import requests
from bs4 import BeautifulSoup
from gensim.models import Word2Vec

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
url = "https://en.wikipedia.org/wiki/Global_warming"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

source = response.text

print("Page loaded successfully")
# Out:
# Page loaded successfully

# %%
soup = bs.BeautifulSoup(source, 'lxml')

text = ""

for paragraph in soup.find_all('p'):
    text += paragraph.text

print(text[:1000])
# Out:
# Present-day climate change includes both global warming—the ongoing increase in global average temperature—and its wider effects on Earth's climate system. Climate change in a broader sense also includes previous long-term changes to Earth's climate. The modern-day rise in global temperatures is driven by human activities, especially fossil fuel (coal, oil and natural gas) burning since the Industrial Revolution.[3][4] Fossil fuel use, deforestation, and some agricultural and industrial practices release greenhouse gases.[5] These gases absorb some of the heat that the Earth radiates after it warms from sunlight, warming the lower atmosphere. Earth's atmosphere now has roughly 50% more carbon dioxide, the main gas driving global warming, than it did at the end of the pre-industrial era, reaching levels not seen for millions of years.[6]
# ...

# %%
text = re.sub(r'\[[0-9]*\]', ' ', text)
text = re.sub(r'\s+', ' ', text)

text = text.lower()

text = re.sub(r'\d', ' ', text)
text = re.sub(r'\s+', ' ', text)

print(text[:1000])
# Out:
#  present-day climate change includes both global warming—the ongoing increase in global average temperature—and its wider effects on earth's climate system. climate change in a broader sense also includes previous long-term changes to earth's climate. the modern-day rise in global temperatures is driven by human activities, especially fossil fuel (coal, oil and natural gas) burning since the industrial revolution. fossil fuel use, deforestation, and some agricultural and industrial practices release greenhouse gases. these gases absorb some of the heat that the earth radiates after it warms from sunlight, warming the lower atmosphere. earth's atmosphere now has roughly % more carbon dioxide, the main gas driving global warming, than it did at the end of the pre-industrial era, reaching levels not seen for millions of years. climate change has an increasingly large impact on the environment. deserts are expanding, while heat waves and wildfires are becoming more common. amplified warm
# ...

# %%
nltk.download('punkt_tab')
sentences = nltk.sent_tokenize(text)

print(sentences[:5])
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [" present-day climate change includes both global warming—the ongoing increase in global average temperature—and its wider effects on earth's climate system.", "climate change in a broader sense also includes previous long-term changes to earth's climate.", 'the modern-day rise in global temperatures is driven by human activities, especially fossil fuel (coal, oil and natural gas) burning since the industrial revolution.', 'fossil fuel use, deforestation, and some agricultural and industrial practices release greenhouse gases.', 'these gases absorb some of the heat that the earth radiates after it warms from sunlight, warming the lower atmosphere.']

# %%
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

print(sentences[:5])
# Out:
# [['present-day', 'climate', 'change', 'includes', 'both', 'global', 'warming—the', 'ongoing', 'increase', 'in', 'global', 'average', 'temperature—and', 'its', 'wider', 'effects', 'on', 'earth', "'s", 'climate', 'system', '.'], ['climate', 'change', 'in', 'a', 'broader', 'sense', 'also', 'includes', 'previous', 'long-term', 'changes', 'to', 'earth', "'s", 'climate', '.'], ['the', 'modern-day', 'rise', 'in', 'global', 'temperatures', 'is', 'driven', 'by', 'human', 'activities', ',', 'especially', 'fossil', 'fuel', '(', 'coal', ',', 'oil', 'and', 'natural', 'gas', ')', 'burning', 'since', 'the', 'industrial', 'revolution', '.'], ['fossil', 'fuel', 'use', ',', 'deforestation', ',', 'and', 'some', 'agricultural', 'and', 'industrial', 'practices', 'release', 'greenhouse', 'gases', '.'], ['these', 'gases', 'absorb', 'some', 'of', 'the', 'heat', 'that', 'the', 'earth', 'radiates', 'after', 'it', 'warms', 'from', 'sunlight', ',', 'warming', 'the', 'lower', 'atmosphere', '.']]

# %%
model = Word2Vec(sentences, vector_size=100, min_count=1)

print("Model trained successfully")
# Out:
# Model trained successfully

# %%
words = model.wv.index_to_key

print(words[:20])
# Out:
# ['.', ',', 'the', 'and', 'of', 'to', 'in', 'climate', 'is', 'a', 'change', 'warming', 'as', 'for', 'that', 'by', 'are', 'global', 'have', 'emissions']

# %%
vector = model.wv['global']

print(vector)
# Out:
# [-0.12759218  0.19199507  0.00751355  0.02653129  0.09984548 -0.25927067
#   0.06196469  0.4218744  -0.22242908 -0.13774168 -0.05212203 -0.2702283
#   0.071255    0.07000926  0.17328864 -0.12154344  0.10329737 -0.08210858
#  -0.09374625 -0.35480705  0.10293195  0.0160612   0.13766026 -0.13541764
#  -0.01269137  0.00637969 -0.18478742 -0.09158204 -0.13477996  0.07845654
#   0.15441795  0.02693786  0.04700523 -0.18949161 -0.02096308  0.2415621
#   0.03431601 -0.04194575 -0.08572558 -0.25577602  0.07890299 -0.19073443
#  -0.08674928  0.09394918  0.14523199 -0.04434514 -0.14884818 -0.05290335
#   0.0800466   0.08192085  0.16133842 -0.19183207 -0.01989752 -0.07372849
#  -0.13042337  0.04694349  0.10465372 -0.00046843 -0.16275835  0.09469459
#   0.03389378  0.01963687  0.09124994 -0.00867927 -0.22306196  0.18494815
#   0.0734596   0.16152756 -0.26328126  0.18243639 -0.06218118  0.12617409
#   0.20854244  0.03749074  0.17737082  0.13646169  0.05402564 -0.01153022
# ...

# %%
similar = model.wv.most_similar('global')

print(similar)
# Out:
# [(',', 0.9989481568336487), ('and', 0.9989175200462341), ('to', 0.9988535046577454), ('the', 0.9988213181495667), ('that', 0.9988179802894592), ('for', 0.9987569451332092), ('climate', 0.9987300634384155), ('of', 0.9987152218818665), ('with', 0.998656153678894), ('in', 0.9985991716384888)]
