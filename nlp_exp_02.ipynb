# %% [markdown]
# <a href="https://colab.research.google.com/github/harikagirigari/nlplab/blob/main/nlp_exp_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3a6a135b-9e3c-4505-b248-21159853756a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a6a135b-9e3c-4505-b248-21159853756a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output=pd.read_csv('/content/Customers.csv' ,sep='\t')

# %%
output
# Out:
#      CustomerID,Gender,Age,Annual Income ($),Spending Score (1-100),Profession,Work Experience,Family Size
# 0                     1,Male,19,15000,39,Healthcare,1,4
# 1                       2,Male,21,35000,81,Engineer,3,3
# 2                      3,Female,20,86000,6,Engineer,1,1
# 3                       4,Female,23,59000,77,Lawyer,0,2
# 4                5,Female,31,38000,40,Entertainment,2,6
# ...                                                 ...
# 1995                1996,Female,71,184387,40,Artist,8,7
# 1996                 1997,Female,91,73158,32,Doctor,7,7
# 1997               1998,Male,87,90961,14,Healthcare,9,2
# 1998                1999,Male,77,182109,4,Executive,7,2
# 1999           2000,Male,90,110610,52,Entertainment,5,2
#
# [2000 rows x 1 columns]

# %%
with open('/content/Customers.csv', 'r', encoding='utf-8') as f:
  output=f.read()
print(output)
# Out:
# CustomerID,Gender,Age,Annual Income ($),Spending Score (1-100),Profession,Work Experience,Family Size
# 1,Male,19,15000,39,Healthcare,1,4
# 2,Male,21,35000,81,Engineer,3,3
# 3,Female,20,86000,6,Engineer,1,1
# 4,Female,23,59000,77,Lawyer,0,2
# 5,Female,31,38000,40,Entertainment,2,6
# 6,Female,22,58000,76,Artist,0,2
# 7,Female,35,31000,6,Healthcare,1,3
# 8,Female,23,84000,94,Healthcare,1,3
# 9,Male,64,97000,3,Engineer,0,3
# 10,Female,30,98000,72,Artist,1,4
# 11,Male,67,7000,14,Engineer,1,3
# 12,Female,35,93000,99,Healthcare,4,4
# 13,Female,58,80000,15,Executive,0,5
# 14,Female,24,91000,77,Lawyer,1,1
# 15,Male,37,19000,13,Doctor,0,1
# 16,Male,22,51000,79,Healthcare,1,2
# 17,Female,35,29000,35,Homemaker,9,5
# 18,Male,20,89000,66,Healthcare,1,6
# 19,Male,52,20000,29,Entertainment,1,4
# 20,Female,35,62000,98,Artist,0,1
# 21,Male,35,96000,35,Homemaker,12,1
# 22,Male,25,4000,73,Healthcare,3,4
# 23,Female,46,42000,5,Artist,13,2
# 24,Male,31,71000,73,Artist,5,2
# ...

# %%
# !pip install PyPDF2
import PyPDF2
pdf_file = open('/content/6CS1016 SEAD Syllabus (1).pdf', 'rb')
pdf_reader = PyPDF2.PdfReader(pdf_file)
page = pdf_reader.pages[0]
text = page.extract_text()
print(text)
pdf_file.close()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.6 MB/s eta 0:00:00
# ...
# Course Title Software Engineering and Agile Development
# Course Code 6CS 1016 Course Category
# Version
# Co-requisite
# Course
# Coordinator
# Course
# Objectives
# Course
# Outcome
# 1
# 2
# 3
# 4
# Module 1.0
# Module -I Dr. Sengottaiyan N Approval Details Core
# This course provides a comprehensive overview of software engineering principles
# methodologies, and tools. It covers the software development lifecycle (SDLC), with a
# Course strong emphasis on Agile methodologies, including Scrum and Extreme Programming
# Deseription (XP). Students will gain the knowledge to manage software development efficiently
# maintain code quality, and adapt to customer needs in dynamic, real-world environments. ACM
# Pre-requisite
# Name CREDITS
# LT P
# 0
# Introduction: 3
# CO Statement Understand the fundamental concepts of software engineering and the SDLC
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
input = requests.get('https://www.kaggle.com/datasets/uciml/electric-power-consumption-data-set?resource=download')

# %%
input
# Out:
# <Response [200]>

# %%
input.content
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n\r\n<head>\r\n  <title>Household Electric Power Consumption | Kaggle</title>\r\n  <meta charset="utf-8" />\r\n    <meta name="robots" content="index, follow" />\r\n  <meta name="description" content="time series analysis- regression / clustering" />\r\n    <meta name="keywords" content="electricity" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">\r\n  <meta name="theme-color" content="#008ABC" />\r\n  <script nonce="GXkN7aUWdeVQS64iaaZjbA==" type="text/javascript">\r\n    window["pageRequestStartTime"] = 1768294547382;\r\n    window["pageRequestEndTime"] = 1768294547387;\r\n    window["initialPageLoadStartTime"] = new Date().getTime();\r\n  </script>\r\n  <script nonce="GXkN7aUWdeVQS64iaaZjbA==" id="gsi-client" src="https://accounts.google.com/gsi/client" async defer></script>\r\n  <script nonce="GXkN7aUWdeVQS64iaaZjbA==">window.KAGGLE_JUPYTERLAB_PATH = "/static/ass
# ...

# %%
sb=BeautifulSoup(input.text,'html.parser')
sb.find_all('p')
# Out:
# <bound method Tag.find of
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Household Electric Power Consumption | Kaggle</title>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="robots"/>
# <meta content="time series analysis- regression / clustering" name="description"/>
# <meta content="electricity" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="#008ABC" name="theme-color">
# <script nonce="GXkN7aUWdeVQS64iaaZjbA==" type="text/javascript">
#     window["pageRequestStartTime"] = 1768294547382;
#     window["pageRequestEndTime"] = 1768294547387;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# <script async="" defer="" id="gsi-client" nonce="GXkN7aUWdeVQS64iaaZjbA==" src="https://accounts.google.com/gsi/client"></script>
# ...
